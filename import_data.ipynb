# %% [markdown]
# <a href="https://colab.research.google.com/github/amandarcrangel/project_studies_fiap/blob/main/import_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

vendas = pd.read_parquet ("vendas_zoop_bronze.parquet")
estoques = pd.read_parquet ("estoques_zoop_bronze.parquet")
redes_sociais = pd.read_parquet ("redes_sociais_zoop_bronze.parquet")

# %%
vendas.head()
# Out:
#    ID_venda  Dia  Mês   Ano   Horario Canal_venda Origem_venda  ID_produto  \
# 0         0   20    8  2021  08:58:00      Loja 2         Loja           3
# 1         1   20    8  2021  11:32:00      Loja 1         Loja          14
# 2         2   20    8  2021  13:19:00      Loja 1         Loja          29
# 3         3   20    8  2021  13:42:00      Loja 2         Loja           3
# 4         4   20    8  2021  14:49:00      Loja 1         Loja           8
#
#            Produto Categoria_produto  ...  Quantidade   Metodo_pagamento  \
# 0        Cafeteira  Eletrodomésticos  ...           3   Cartão de débito
# 1       Impressora       Eletrônicos  ...           1           Dinheiro
# 2  Máquina de café  Eletrodomésticos  ...           2  Cartão de crédito
# 3        Cafeteira  Eletrodomésticos  ...           1                PIX
# 4      Micro-ondas  Eletrodomésticos  ...           1   Cartão de débito
#
# ...

# %%
estoques.head()
# Out:
#    ID_estoque  ID_produto             Produto Categoria_produto        Data  \
# 0           0           0        Smart_TV_55"       Eletrônicos  2021/07/01
# 1           1           1            Frigobar  Eletrodomésticos  2021/07/01
# 2           2           2  Ventilador_de_teto  Eletrodomésticos  2021/07/01
# 3           3           3           Cafeteira  Eletrodomésticos  2021/07/01
# 4           4           4          Smartphone       Eletrônicos  2021/07/01
#
#     Horario  Quantidade_em_estoque  Quantidade_novos_produtos  \
# 0  21:45:00                    100                         20
# 1  20:13:00                    100                         29
# 2  13:30:00                    100                         16
# 3  06:20:00                    100                         10
# 4  14:33:00                    100                         49
#
#    Quantidade_vendida
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# ...

# %%
pd.set_option('display.max_columns', 100)
redes_sociais.head()
# Out:
#    ID_social        Data  Influencia_autor   Plataforma     Nome_produto  \
# 0          0  2021-09-07              7864  X (Twitter)        Cafeteira
# 1          1  2021-09-30             60503  X (Twitter)       Impressora
# 2          2  2021-09-19             86828  X (Twitter)  Máquina de café
# 3          3  2021-09-19             28615  X (Twitter)        Cafeteira
# 4          4  2021-09-12             38424     Facebook      Micro-ondas
#
#   Categoria_produto                                         Comentario
# 0  Eletrodomésticos  Estou impressionado com a qualidade e a eficiê...
# 1       Eletrônicos  Produto ok, mas achei o preço um pouco elevado...
# 2  Eletrodomésticos  Produto incrível! Desempenho muito acima da mé...
# 3  Eletrodomésticos  Produto bom, mas nada excepcional. #Cafeteira ...
# 4  Eletrodomésticos  Produto ruim. Esperava muito mais. #Micro-onda...
